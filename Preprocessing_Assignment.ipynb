# %% [markdown]
# <a href="https://colab.research.google.com/github/JustinJeyakumar/Inceptez_Batch19/blob/Completed_Exercises/Preprocessing_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
url = 'https://raw.githubusercontent.com/balaji2v/Inceptez_Batch19/main/Demand_txn_updated.csv'
df = pd.read_csv(url)
df
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978        7/31/2018
# 1      Hyderabad         Take Away              4064        7/31/2018
# 2      Hyderabad         Main Hall               965        7/31/2018
# 3      Hyderabad           Express              9978        7/31/2018
# 4      Hyderabad           Express              1045        7/31/2018
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056         8/1/2016
# 30227     Mumbai         Take Away              4058         8/1/2016
# 30228     Mumbai           Dine-in               964         8/1/2016
# 30229     Mumbai         Take Away              4066         8/1/2016
# 30230     Mumbai          Delivery              4061         8/1/2016
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %% [markdown]
# #Read the demand transaction file and print the first 15 rows and dtypes

# %%
df.head(15)
# Out:
#          City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0   Hyderabad         Take Away              9978        7/31/2018
# 1   Hyderabad         Take Away              4064        7/31/2018
# 2   Hyderabad         Main Hall               965        7/31/2018
# 3   Hyderabad           Express              9978        7/31/2018
# 4   Hyderabad           Express              1045        7/31/2018
# 5   Hyderabad          Delivery              4056        7/31/2018
# 6   Hyderabad         Take Away              4065        7/31/2018
# 7   Hyderabad           Express              4058        7/31/2018
# 8   Hyderabad           Express              4057        7/31/2018
# 9   Hyderabad           Express              4056        7/31/2018
# 10  Hyderabad          Delivery              4061        7/31/2018
# 11  Hyderabad           Express              4055        7/31/2018
# 12  Hyderabad         Take Away              4061        7/31/2018
# ...

# %% [markdown]
# Convert the transaction date column to a date column using pd.to_datetime function

# %%
df['Transaction_Date'] = pd.to_datetime(df['Transaction_Date'])
df
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978       2018-07-31
# 1      Hyderabad         Take Away              4064       2018-07-31
# 2      Hyderabad         Main Hall               965       2018-07-31
# 3      Hyderabad           Express              9978       2018-07-31
# 4      Hyderabad           Express              1045       2018-07-31
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056       2016-08-01
# 30227     Mumbai         Take Away              4058       2016-08-01
# 30228     Mumbai           Dine-in               964       2016-08-01
# 30229     Mumbai         Take Away              4066       2016-08-01
# 30230     Mumbai          Delivery              4061       2016-08-01
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %% [markdown]
# Subset the dataframe for transaction date greater than '2016-08-01'

# %%
df[(df['Transaction_Date'] > '2016-08-01')]
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978       2018-07-31
# 1      Hyderabad         Take Away              4064       2018-07-31
# 2      Hyderabad         Main Hall               965       2018-07-31
# 3      Hyderabad           Express              9978       2018-07-31
# 4      Hyderabad           Express              1045       2018-07-31
# ...          ...               ...               ...              ...
# 30187     Mumbai         Take Away              4059       2016-08-02
# 30188     Mumbai         Main Hall               966       2016-08-02
# 30189     Mumbai         Take Away              4065       2016-08-02
# 30190     Mumbai          Delivery              4057       2016-08-02
# 30191     Mumbai         Take Away              4061       2016-08-02
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %% [markdown]
# unique values in Mapped_Sales_Type

# %%
my_list=df.columns.values.tolist()
my_list
# df.Mapped_Sales_Type.unique()
# Out:
# ['City',
#  'Mapped_Sales_Type',
#  'Mapped_Item_Code',
#  'Transaction_Date',
#  'Quantity_Sold',
#  'Median_Price',
#  'Average_Tax_Percent',
#  'Effective_Price',
#  'Percent_Quantity_With_Discount',
#  'Avg_Discount_Percent_On_Discounted_Items',
#  'Year',
#  'Month',
#  'Day',
#  'Car_sales',
#  'F_and_B_Inflation',
#  'F_and_B_Inflation_Adjusted_Effective_Price',
#  'F_and_B_Inflation_Adjusted_Median_Price',
#  'First_Week_Of_The_Month_Dummy',
#  'Last_Week_Of_The_Month_Dummy',
#  'Day_Of_The_Week_Seasonality',
#  'Month_Of_The_Year_Seasonality',
#  'Two_Wheeler_sales']

# %% [markdown]
# #5.	Subset the entire dataframe, based on the below condition, to a new dataframe and work on the following questions
# # a.	Condition: Avg_Discount_Percent_On_Discounted_Items should be less than 1.

# %%
new_df=df[(df['Avg_Discount_Percent_On_Discounted_Items'] < 1)]
new_df
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 5      Hyderabad          Delivery              4056       2018-07-31
# 10     Hyderabad          Delivery              4061       2018-07-31
# 20     Hyderabad           Dine-in               966       2018-07-31
# 24     Hyderabad           Dine-in               965       2018-07-31
# 26     Hyderabad          Delivery              4068       2018-07-31
# ...          ...               ...               ...              ...
# 30198     Mumbai         Take Away              4055       2016-08-01
# 30201     Mumbai           Dine-in               978       2016-08-01
# 30212     Mumbai           Dine-in               970       2016-08-01
# 30213     Mumbai           Dine-in               965       2016-08-01
# 30226     Mumbai         Take Away              4056       2016-08-01
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %% [markdown]
# Check for sanity if the new dataframe contains Avg_Discount_Percent_On_Discounted_Items greater than or equal to 1.0

# %%
new_df[(new_df['Avg_Discount_Percent_On_Discounted_Items'] >= 1)]
# Out:
# Empty DataFrame
# Columns: [City, Mapped_Sales_Type, Mapped_Item_Code, Transaction_Date, Quantity_Sold, Median_Price, Average_Tax_Percent, Effective_Price, Percent_Quantity_With_Discount, Avg_Discount_Percent_On_Discounted_Items, Year, Month, Day, Car_sales, F_and_B_Inflation, F_and_B_Inflation_Adjusted_Effective_Price, F_and_B_Inflation_Adjusted_Median_Price, First_Week_Of_The_Month_Dummy, Last_Week_Of_The_Month_Dummy, Day_Of_The_Week_Seasonality, Month_Of_The_Year_Seasonality, Two_Wheeler_sales]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# # 6.	Groupby 'City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date' and perform following aggregate operations on respective columns as mentioned (note: Only one groupby to do all the below aggregations)
# # a.	Quantity_Sold – sum
# # b.	Median_Price – median
# # c.	Effective_Price – median

# %%
df.groupby(['City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date'])['Quantity_Sold'].sum()
# Out:
# City     Mapped_Sales_Type  Mapped_Item_Code  Transaction_Date
# Chennai  Bakery             4057              2017-08-05          110
#                             9978              2018-01-22          105
#          Delivery           4055              2017-08-04          377
#                                               2017-08-05          377
#                                               2017-08-06          638
#                                                                  ...
# Mumbai   Take Away          4068              2017-01-09          200
#                                               2017-01-10          199
#                                               2017-01-11          239
#                                               2017-01-12          233
#                                               2017-01-13          273
# Name: Quantity_Sold, Length: 30231, dtype: int64

# %%
df.groupby(['City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date'])['Median_Price'].median()
# Out:
# City     Mapped_Sales_Type  Mapped_Item_Code  Transaction_Date
# Chennai  Bakery             4057              2017-08-05          223.0
#                             9978              2018-01-22          178.0
#          Delivery           4055              2017-08-04          260.0
#                                               2017-08-05          260.0
#                                               2017-08-06          260.0
#                                                                   ...
# Mumbai   Take Away          4068              2017-01-09          405.0
#                                               2017-01-10          405.0
#                                               2017-01-11          405.0
#                                               2017-01-12          405.0
#                                               2017-01-13          405.0
# Name: Median_Price, Length: 30231, dtype: float64

# %%
df.groupby(['City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date'])['Effective_Price'].median()
# Out:
# City     Mapped_Sales_Type  Mapped_Item_Code  Transaction_Date
# Chennai  Bakery             4057              2017-08-05          221.000000
#                             9978              2018-01-22          154.250000
#          Delivery           4055              2017-08-04          264.113759
#                                               2017-08-05          264.138571
#                                               2017-08-06          264.223814
#                                                                      ...
# Mumbai   Take Away          4068              2017-01-09          424.140000
#                                               2017-01-10          424.140000
#                                               2017-01-11          424.140000
#                                               2017-01-12          424.140000
#                                               2017-01-13          423.201358
# Name: Effective_Price, Length: 30231, dtype: float64

# %% [markdown]
# 7. Display the data for Effective_Price = not null and just print the last 5 rows (hint: use .notnull function)

# %%
pd.notnull(df['Effective_Price'])
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 30226    True
# 30227    True
# 30228    True
# 30229    True
# 30230    True
# Name: Effective_Price, Length: 30231, dtype: bool

# %% [markdown]
# 8. Display the data for city = Chennai AND Mapped_Sales_Type = Delivery and print top 5 records (hint use loc function to subset, then “&” operator to filter both the above cities)

# %%
temp_df=df.loc[:,:]
temp_df
temp_df[(temp_df['City'] == 'Chennai') & (temp_df['Mapped_Sales_Type'] == 'Delivery')].head(5)
# Out:
#          City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 8379  Chennai          Delivery              4055       2018-02-05
# 8384  Chennai          Delivery              4068       2018-02-05
# 8387  Chennai          Delivery              4064       2018-02-05
# 8388  Chennai          Delivery              4058       2018-02-05
# 8392  Chennai          Delivery              4061       2018-02-05
#
#       Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 8379            544        281.10                 0.05       262.502194
# 8384            129        566.43                 0.05       562.110000
# 8387            186        619.34                 0.05       617.659733
# 8388            287        259.19                 0.05       239.381307
# 8392            128        850.62                 0.05       855.697647
#
#       Percent_Quantity_With_Discount  \
# 8379                             NaN
# 8384                             NaN
# ...

# %% [markdown]
# 9. Display the data for the column “Day” with values Mon, Tue and Wed (hint: use .isin function)

# %%
df[df['Day'].isin(['Mon','Tue','Wed'])]
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978       2018-07-31
# 1      Hyderabad         Take Away              4064       2018-07-31
# 2      Hyderabad         Main Hall               965       2018-07-31
# 3      Hyderabad           Express              9978       2018-07-31
# 4      Hyderabad           Express              1045       2018-07-31
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056       2016-08-01
# 30227     Mumbai         Take Away              4058       2016-08-01
# 30228     Mumbai           Dine-in               964       2016-08-01
# 30229     Mumbai         Take Away              4066       2016-08-01
# 30230     Mumbai          Delivery              4061       2016-08-01
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %% [markdown]
# Display the data for Percent_Quantity_With_Discount not equal to 0.0 (hint: loc function with != operator)

# %%
df.loc[df['Percent_Quantity_With_Discount'] != 0]
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978       2018-07-31
# 1      Hyderabad         Take Away              4064       2018-07-31
# 2      Hyderabad         Main Hall               965       2018-07-31
# 3      Hyderabad           Express              9978       2018-07-31
# 4      Hyderabad           Express              1045       2018-07-31
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056       2016-08-01
# 30227     Mumbai         Take Away              4058       2016-08-01
# 30228     Mumbai           Dine-in               964       2016-08-01
# 30229     Mumbai         Take Away              4066       2016-08-01
# 30230     Mumbai          Delivery              4061       2016-08-01
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %% [markdown]
# 11. Add a column “Range” to the existing dataframe for below condition
#
# a. 1 for Effective_Price > 500
#
# b. 0.5 otherwise

# %%
def func(x):
    if x['Effective_Price'] > 0:
        return 1
    else:
        return 0.5



df['Range'] = df.apply(func , axis = 1)
df
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978       2018-07-31
# 1      Hyderabad         Take Away              4064       2018-07-31
# 2      Hyderabad         Main Hall               965       2018-07-31
# 3      Hyderabad           Express              9978       2018-07-31
# 4      Hyderabad           Express              1045       2018-07-31
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056       2016-08-01
# 30227     Mumbai         Take Away              4058       2016-08-01
# 30228     Mumbai           Dine-in               964       2016-08-01
# 30229     Mumbai         Take Away              4066       2016-08-01
# 30230     Mumbai          Delivery              4061       2016-08-01
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %% [markdown]
# 12. Read the demand transaction file again and perform following operations for practice
#
# a. Handle the missing values in the column Percent_Quantity_With_Discount with strategy = mean

# %%
df['Percent_Quantity_With_Discount'].fillna(df['Percent_Quantity_With_Discount'].mean(), inplace = True)
df
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978       2018-07-31
# 1      Hyderabad         Take Away              4064       2018-07-31
# 2      Hyderabad         Main Hall               965       2018-07-31
# 3      Hyderabad           Express              9978       2018-07-31
# 4      Hyderabad           Express              1045       2018-07-31
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056       2016-08-01
# 30227     Mumbai         Take Away              4058       2016-08-01
# 30228     Mumbai           Dine-in               964       2016-08-01
# 30229     Mumbai         Take Away              4066       2016-08-01
# 30230     Mumbai          Delivery              4061       2016-08-01
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...
