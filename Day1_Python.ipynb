# %%
print("Hello World !!")
# Out:
# Hello World !!

# %%
# Example of Dynamically Type Language

a = 100
b = "Balaji"

# %%
type (a)
# Out:
# int

# %%
type (b)
# Out:
# str

# %%
c= 9.2233

# %%
type (c)
# Out:
# float

# %%
#type casting

# %%
int (c)
# Out:
# 9

# %%
c = int (c)

# %%
type (c)
# Out:
# int

# %%
4_c = 100
# Out:
#   File "<ipython-input-12-c1534a86e51f>", line 1
#     4_c = 100
#      ^
# SyntaxError: invalid token

# %%
C = 100

# %%
#pep8, 2

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
var_bala =100

# %%
var_Bala_Typin

# %%
VAR = 100

# %%
print (c)
# Out:
# 9

# %%
print(C)
# Out:
# 100

# %%
_= 100

# %%
type (_)
# Out:
# int

# %%
&_bala = 100
# Out:
#   File "<ipython-input-18-cca6b90062c2>", line 1
#     &_bala = 100
#     ^
# SyntaxError: invalid syntax

# %%
a = 101
b = 20

# %%
c = a + b

# %%
d = a - b

# %%
d
# Out:
# 80

# %%
e = a/b
print (e)
# Out:
# 5.05

# %%
e = a % b
print (e)
# Out:
# 1

# %%
a = 2
b = 3

# %%
c = a**b

# %%
# 2 to the power 3
print (c)
# Out:
# 8

# %%
print (c)
# Out:
# 120

# %%
x = 5

# %%
x += 3

# %%
x
# Out:
# 8

# %%
a
# Out:
# 8

# %%
a = 2

# %%
a == x
# Out:
# False

# %%
a != x
# Out:
# True

# %%
a > x
# Out:
# False

# %%
a < x
# Out:
# True

# %%
a = 100
b = "Balaji"

# %%
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-ca730b97bf8a> in <module>()
# ----> 1 a+b
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
b + str(a)
# Out:
# 'Balaji100'

# %%
a + int(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-990e2a0f824e> in <module>()
# ----> 1 a + int(b)
#
# ValueError: invalid literal for int() with base 10: 'Balaji'

# %%
a <= x
# Out:
# False

# %%
x  = 8

# %%
x < 5 or  x < 10
# Out:
# True

# %%
not (x <5 )
# Out:
# True

# %%
range (0)
# Out:
# /bin/bash: 5: No such file or directory

# %%
a = input (adad)

# %%
# single line comment

# %%
#comment
def function1():
    """My first function to print the statement"""
    print('This is my first function')

# %%
def balaji(): 
#My stupid mistakes
 """My first function to print the statement"""
 print("My stupid mistakes Balaji2.0")

# %%
balaji()
# Out:
# My stupid mistakes Balaji2.0

# %%
print(balaji.__doc__)
# Out:
# My first function to print the statement

# %%
"""My first line of comment 
My second line of comment 
My third line of comment"""
# Out:
# 'My first line of comment \nMy second line of comment \nMy third line of comment'

# %%
def addition_function(a, b):
    """Function to add two number"""
    #print (a)
    #print (b)
    print (a)
    return a + b

# %%
first_number = input("Enter First number:")
second_number = input("Enter Second number:")
print("First Number is: " + first_number)
print("Second Number is: " + second_number)
# Out:
# Enter First number:20
# Enter Second number:100
# First Number is: 20
# Second Number is: 100

# %%
addition_function(10, 12)
# Out:
# 10
# 22

# %%
# Take any number, identify it is ODD or even; then print odd and even number separately,

# %%
#Get the number as Input, Identify a prime number.

# %%
# Print the odd and even numbers from 1 to 100

# %%
# Print the prime numbers  from 1 to 100

# %%
x = range(5)
for n in x:
  print(n)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a = 33
b = 200
if b > a:
  print("b is greater than a")
# Out:
# b is greater than a

# %%
num = int(input("Enter a number: "))
mod = num % 2
if mod > 0:
    print("This is an odd number.")
else:
    print("This is an even number.")
# Out:
# Enter a number: 20
# This is an even number.

# %%
i = 1
while i < 6:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1
while i < 6:
  print(i)
  if i == 3:
    print(i)
    break
  i += 1
# Out:
# 1
# 2
# 3
# 3

# %%
i = 1
while i < 6:
  print(i)
  if i == 3:
    print(i)
    continue
  i += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# ...

# %%
for x in "banana":
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
num = int(input("Enter a number: "))
if(a%2)==0:
    print("It is even")
else:
    print("Odd")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     726         """
# --> 727         parts = [self.recv(flags, copy=copy, track=track)]
#     728         # have first part already, only loop while more to receive
#
# ...
