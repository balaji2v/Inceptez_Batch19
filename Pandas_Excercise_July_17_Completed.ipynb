# %% [markdown]
# <a href="https://colab.research.google.com/github/JustinJeyakumar/Inceptez_Batch19/blob/Completed_Exercises/Pandas_Excercise_July_17_Completed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import the pandas library
# Read the data company.csv in pandas

# %%
import pandas as pd
import io
url = 'https://raw.githubusercontent.com/balaji2v/Inceptez_Batch19/main/company.csv'
df = pd.read_csv(url)
# df = pd.read_table(url)
print(df)
my_list = df.columns.values.tolist()
print(my_list)
# Out:
#      Company   Age  Salary     Place Country
# 0        TCS  20.0     NaN   Chennai   India
# 1    Infosys  30.0     NaN    Mumbai   India
# 2        TCS  35.0  2300.0  Calcutta   India
# 3    Infosys  40.0  3000.0     Delhi   India
# 4        TCS  23.0  4000.0    Mumbai   India
# ..       ...   ...     ...       ...     ...
# 144  Infosys  22.0  8787.0  Calcutta   India
# 145  Infosys  44.0  4034.0     Delhi   India
# 146      TCS  33.0  5034.0    Mumbai   India
# 147  Infosys  22.0  8202.0    Cochin   India
# 148      NaN   NaN     NaN       NaN     NaN
#
# [149 rows x 5 columns]
# ['Company', 'Age', 'Salary', 'Place', 'Country']

# %%
mydict = [{'a': 1, 'b': 2, 'c': 3, 'd': 4},
          {'a': 100, 'b': 200, 'c': 300, 'd': 400},
          {'a': 1000, 'b': 2000, 'c': 3000, 'd': 4000 }]
df = pd.DataFrame(mydict)
df
df.iloc[2]
df.iloc[[0]]
df.iloc[[0,2]]
# Out:
#       a     b     c     d
# 0     1     2     3     4
# 2  1000  2000  3000  4000

# %% [markdown]
# Find the dimension of given data

# %%
# dataframe.size
size = df.size
  
# dataframe.shape
shape = df.shape
  
# dataframe.ndim
df_ndim = df.ndim
  
# series.ndim
#series_ndim = data["age"].ndim
  
# printing size and shape
print("Size = {} \nShape ={} \nShape[0] x Shape[1] = {}".format(size, shape, shape[0]*shape[1]))
  
# printing ndim
#print("ndim of dataframe = {}\nndim of series ={}".
#format(df_ndim, series_ndim))
# Out:
# Size = 149
#  Shape =(149, 1)
#  Shape[0] x Shape[1] = 149

# %% [markdown]
# List down all the columns in data frame

# %%
data = {'Name': ['Justin','Jeyakumar','Jeyabal'], 'Age' : [11,22,33], 'Country' : ['Ind', 'US', 'UK']}
df = pd.DataFrame(df)
print(df)
my_list = df.columns.values.tolist()
print(my_list)
# Out:
#         Name  Age Country
# 0     Justin   11     Ind
# 1  Jeyakumar   22      US
# 2    Jeyabal   33      UK
# ['Name', 'Age', 'Country']

# %% [markdown]
# List the top 10 rows in datframe

# %%
print(df.head(10))
# Out:
#   Company,Age,Salary,Place,Country
# 0            TCS,20,,Chennai,India
# 1         Infosys,30,,Mumbai,India
# 2       TCS,35,2300,Calcutta,India
# 3      Infosys,40,3000,Delhi,India
# 4         TCS,23,4000,Mumbai,India
# 5     Infosys,,5000,Calcutta,India
# 6          TCS,,6000,Chennai,India
# 7     Infosys,23,7000,Mumbai,India
# 8       TCS,34,8000,Calcutta,India
# 9          CTS,45,9000,Delhi,India

# %% [markdown]
# List the last 15 rows in datframe

# %%
print(df.tail(15))
# Out:
#                    Company,Age,Salary,Place,Country
# 134  Tata Consultancy Services,31,8345,Mumbai,India
# 135                      CTS,40,9284,Calcutta,India
# 136                                  ,,,Delhi,India
# 137                        CTS,31,2034,Mumbai,India
# 138                        CTS,44,3033,Cochin,India
# 139                  Congnizant,22,2934,Noida,India
# 140                 Infosys,44,4034,Hyderabad,India
# 141                      TCS,33,5034,Calcutta,India
# 142            Infosys Pvt Lmt,22,8202,Mumbai,India
# 143                      TCS,33,9024,Calcutta,India
# 144                  Infosys,22,8787,Calcutta,India
# 145                     Infosys,44,4034,Delhi,India
# 146                        TCS,33,5034,Mumbai,India
# 147                    Infosys,22,8202,Cochin,India
# 148                                            ,,,,

# %% [markdown]
# Find the number of rows in dataframe

# %%
print(df.iloc[1:])
print(len(df))
count_row = df.shape[0]  # Gives number of rows
count_col = df.shape[1]  # Gives number of columns
print("ROW = {}\nCOLUMN {}".format(count_row, count_col))
# Out:
#     Company,Age,Salary,Place,Country
# 1           Infosys,30,,Mumbai,India
# 2         TCS,35,2300,Calcutta,India
# 3        Infosys,40,3000,Delhi,India
# 4           TCS,23,4000,Mumbai,India
# 5       Infosys,,5000,Calcutta,India
# ..                               ...
# 144   Infosys,22,8787,Calcutta,India
# 145      Infosys,44,4034,Delhi,India
# 146         TCS,33,5034,Mumbai,India
# 147     Infosys,22,8202,Cochin,India
# 148                             ,,,,
#
# [148 rows x 1 columns]
# 149
# ROW = 149
# COLUMN 1

# %% [markdown]
# Check the information of dataframe

# %%
import pandas as pd
import io
url = 'https://raw.githubusercontent.com/balaji2v/Inceptez_Batch19/main/company.csv'
df = pd.read_csv(url)
# df = pd.read_table(url)
print(df)
print(df.info())
print(df.describe())
df.describe(include='all')
df[['Salary','Age']].describe()
# Out:
#      Company   Age  Salary     Place Country
# 0        TCS  20.0     NaN   Chennai   India
# 1    Infosys  30.0     NaN    Mumbai   India
# 2        TCS  35.0  2300.0  Calcutta   India
# 3    Infosys  40.0  3000.0     Delhi   India
# 4        TCS  23.0  4000.0    Mumbai   India
# ..       ...   ...     ...       ...     ...
# 144  Infosys  22.0  8787.0  Calcutta   India
# 145  Infosys  44.0  4034.0     Delhi   India
# 146      TCS  33.0  5034.0    Mumbai   India
# 147  Infosys  22.0  8202.0    Cochin   India
# 148      NaN   NaN     NaN       NaN     NaN
#
# [149 rows x 5 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  140 non-null    object
#  1   Age      130 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
#  4   Country  148 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 5.9+ KB
# None
#               Age       Salary
# count  130.000000   124.000000
# mean    30.484615  5312.467742
# std     11.096640  2573.764683
# min      0.000000  1089.000000
# 25%     22.000000  3030.000000
# 50%     32.500000  5000.000000
# 75%     37.750000  8000.000000
# max     54.000000  9876.000000
#             Salary         Age
# count   124.000000  130.000000
# mean   5312.467742   30.484615
# std    2573.764683   11.096640
# min    1089.000000    0.000000
# 25%    3030.000000   22.000000
# 50%    5000.000000   32.500000
# 75%    8000.000000   37.750000
# max    9876.000000   54.000000

# %% [markdown]
# Check the basic Statistics of Dataframe. Give your inference from the stats

# %%
Cars = {'Brand': ['Honda Civic','Ford Focus','Toyota Corolla','Toyota Corolla','Audi A4'],
        'Price': [22000,27000,25000,29000,35000],
         'Year': [2014,2015,2016,2017,2018]
        }

df = pd.DataFrame(Cars, columns= ['Brand', 'Price','Year'])
print (df)
df[['Price', 'Year']].describe()
# Out:
#             Brand  Price  Year
# 0     Honda Civic  22000  2014
# 1      Ford Focus  27000  2015
# 2  Toyota Corolla  25000  2016
# 3  Toyota Corolla  29000  2017
# 4         Audi A4  35000  2018
#               Price         Year
# count      5.000000     5.000000
# mean   27600.000000  2016.000000
# std     4878.524367     1.581139
# min    22000.000000  2014.000000
# 25%    25000.000000  2015.000000
# 50%    27000.000000  2016.000000
# 75%    29000.000000  2017.000000
# max    35000.000000  2018.000000

# %% [markdown]
# Retrieve 20 to 100 rows and Company and age usig iloc

# %%
df.iloc[20:101, 0:2]
# Out:
#      Company   Age
# 20       TCS  37.0
# 21   Infosys  50.0
# 22       TCS  21.0
# 23   Infosys   NaN
# 24       TCS   NaN
# ..       ...   ...
# 96       TCS   NaN
# 97   Infosys  22.0
# 98       TCS  33.0
# 99       CTS  44.0
# 100      CTS  22.0
#
# [81 rows x 2 columns]

# %% [markdown]
# Retrieve 20 to 100 rows and Company and age usig loc

# %%
lis = []
df.loc[20:100,['Company','Salary']]
# Out:
#      Company  Salary
# 20       TCS  3045.0
# 21   Infosys  3184.0
# 22       TCS  4824.0
# 23   Infosys  5835.0
# 24       TCS  7084.0
# ..       ...     ...
# 96       TCS  7084.0
# 97   Infosys  8943.0
# 98       TCS  8345.0
# 99       CTS  9284.0
# 100      CTS     NaN
#
# [81 rows x 2 columns]

# %% [markdown]
# Chage the data in 100 row and Place as 'Noida'

# %%
df.at[100,'Place']='Pune'
df.iloc[100]
# Out:
# Company      CTS
# Age         22.0
# Salary       NaN
# Place       Pune
# Country    India
# Name: 100, dtype: object

# %% [markdown]
# Change the column 'Place' to 'City'

# %%
df
df.rename(columns = {'Place':'City'}, inplace = True)
df
# Out:
#      Company   Age  Salary      City Country
# 0        TCS  20.0     NaN   Chennai   India
# 1    Infosys  30.0     NaN    Mumbai   India
# 2        TCS  35.0  2300.0  Calcutta   India
# 3    Infosys  40.0  3000.0     Delhi   India
# 4        TCS  23.0  4000.0    Mumbai   India
# ..       ...   ...     ...       ...     ...
# 144  Infosys  22.0  8787.0  Calcutta   India
# 145  Infosys  44.0  4034.0     Delhi   India
# 146      TCS  33.0  5034.0    Mumbai   India
# 147  Infosys  22.0  8202.0    Cochin   India
# 148      NaN   NaN     NaN       NaN     NaN
#
# [149 rows x 5 columns]

# %% [markdown]
# List down the unique data in each columns and find length of unique data

# %%
df.nunique(axis=0)
# df.City.nunique()
# Out:
# Company     6
# Age        29
# Salary     40
# City       11
# Country     1
# dtype: int64

# %% [markdown]
# Rename all the possible labels of column in Company as three labels
# TCS
# CTS
# Infosys

# %%
df
df.loc[df.Company.isin(['TCS','CTS','Infosys'])]
# Out:
#      Company   Age  Salary      City Country
# 0        TCS  20.0     NaN   Chennai   India
# 1    Infosys  30.0     NaN    Mumbai   India
# 2        TCS  35.0  2300.0  Calcutta   India
# 3    Infosys  40.0  3000.0     Delhi   India
# 4        TCS  23.0  4000.0    Mumbai   India
# ..       ...   ...     ...       ...     ...
# 143      TCS  33.0  9024.0  Calcutta   India
# 144  Infosys  22.0  8787.0  Calcutta   India
# 145  Infosys  44.0  4034.0     Delhi   India
# 146      TCS  33.0  5034.0    Mumbai   India
# 147  Infosys  22.0  8202.0    Cochin   India
#
# [134 rows x 5 columns]

# %%
#Where ever you see age as 0 replace with NA

##Hint df[df.Age==20] = np.isnan

# %%
import numpy as np
df[df.Age == 0] = np.isnan
df[df.Age == 0]
df[df.Salary.isna()] = 3000
df.Age.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 144    False
# 145    False
# 146    False
# 147    False
# 148    False
# Name: Age, Length: 149, dtype: bool

# %% [markdown]
# Check how many duplicated data is there?

# %%
import pandas as pd
import io
url = 'https://raw.githubusercontent.com/balaji2v/Inceptez_Batch19/main/company.csv'
# df = pd.read_csv(url)
df = pd.read_table(url)
print(df)
my_list = df.columns.values.tolist()
print(my_list)
df.duplicated().sum()
# Out:
#     Company,Age,Salary,Place,Country
# 0              TCS,20,,Chennai,India
# 1           Infosys,30,,Mumbai,India
# 2         TCS,35,2300,Calcutta,India
# 3        Infosys,40,3000,Delhi,India
# 4           TCS,23,4000,Mumbai,India
# ..                               ...
# 144   Infosys,22,8787,Calcutta,India
# 145      Infosys,44,4034,Delhi,India
# 146         TCS,33,5034,Mumbai,India
# 147     Infosys,22,8202,Cochin,India
# 148                             ,,,,
#
# [149 rows x 1 columns]
# ['Company,Age,Salary,Place,Country']
# 8

# %% [markdown]
# Remove all duplicated rowise data

# %%
df.drop_duplicates()
# Out:
#          Company,Age,Salary,Place,Country
# 0                   TCS,20,,Chennai,India
# 1                Infosys,30,,Mumbai,India
# 2              TCS,35,2300,Calcutta,India
# 3             Infosys,40,3000,Delhi,India
# 4                TCS,23,4000,Mumbai,India
# ..                                    ...
# 140       Infosys,44,4034,Hyderabad,India
# 141            TCS,33,5034,Calcutta,India
# 142  Infosys Pvt Lmt,22,8202,Mumbai,India
# 143            TCS,33,9024,Calcutta,India
# 148                                  ,,,,
#
# [141 rows x 1 columns]

# %% [markdown]
# Remove the column 'Country'

# %%
import pandas as pd
import io
url = 'https://raw.githubusercontent.com/balaji2v/Inceptez_Batch19/main/company.csv'
df = pd.read_csv(url)
# df = pd.read_table(url)
print(df)
my_list = df.columns.values.tolist()
print(my_list)
df
df.drop(['Country'], axis = 1, inplace = True, errors = 'ignore')
# df.drop(df.columns[3], axis=1, inplace=True)
df
# Out:
#      Company   Age  Salary     Place Country
# 0        TCS  20.0     NaN   Chennai   India
# 1    Infosys  30.0     NaN    Mumbai   India
# 2        TCS  35.0  2300.0  Calcutta   India
# 3    Infosys  40.0  3000.0     Delhi   India
# 4        TCS  23.0  4000.0    Mumbai   India
# ..       ...   ...     ...       ...     ...
# 144  Infosys  22.0  8787.0  Calcutta   India
# 145  Infosys  44.0  4034.0     Delhi   India
# 146      TCS  33.0  5034.0    Mumbai   India
# 147  Infosys  22.0  8202.0    Cochin   India
# 148      NaN   NaN     NaN       NaN     NaN
#
# [149 rows x 5 columns]
# ['Company', 'Age', 'Salary', 'Place', 'Country']
#      Company   Age  Salary     Place
# 0        TCS  20.0     NaN   Chennai
# 1    Infosys  30.0     NaN    Mumbai
# 2        TCS  35.0  2300.0  Calcutta
# 3    Infosys  40.0  3000.0     Delhi
# 4        TCS  23.0  4000.0    Mumbai
# ..       ...   ...     ...       ...
# 144  Infosys  22.0  8787.0  Calcutta
# 145  Infosys  44.0  4034.0     Delhi
# 146      TCS  33.0  5034.0    Mumbai
# 147  Infosys  22.0  8202.0    Cochin
# 148      NaN   NaN     NaN       NaN
#
# [149 rows x 4 columns]

# %% [markdown]
# Remove the row number 137

# %%
update_df = df.drop([df.index[136]])
update_df
# Out:
#     Company,Age,Salary,Place,Country
# 0              TCS,20,,Chennai,India
# 2         TCS,35,2300,Calcutta,India
# 3        Infosys,40,3000,Delhi,India
# 4           TCS,23,4000,Mumbai,India
# 5       Infosys,,5000,Calcutta,India
# ..                               ...
# 144   Infosys,22,8787,Calcutta,India
# 145      Infosys,44,4034,Delhi,India
# 146         TCS,33,5034,Mumbai,India
# 147     Infosys,22,8202,Cochin,India
# 148                             ,,,,
#
# [148 rows x 1 columns]

# %% [markdown]
# Find number of each labels in Company

# %%
df.Company.value_counts()
# Out:
# TCS                          53
# Infosys                      45
# CTS                          36
# Tata Consultancy Services     2
# Congnizant                    2
# Infosys Pvt Lmt               2
# Name: Company, dtype: int64

# %% [markdown]
# Find number of each labels in City

# %%
df.Place.value_counts()
# Out:
# Mumbai        37
# Calcutta      33
# Chennai       14
# Delhi         14
# Cochin        13
# Noida          8
# Hyderabad      8
# Podicherry     3
# Pune           2
# Bhopal         1
# Nagpur         1
# Name: Place, dtype: int64

# %% [markdown]
# Find Number of Null Values in each column

# %%
df.isna().sum()
# Out:
# Company     9
# Age        19
# Salary     25
# Place      15
# Country     1
# dtype: int64

# %% [markdown]
# Remove all Null values in Salary

# %%
df.Salary.isna().sum()
df2=df.dropna(subset=['Salary'])
df2.Salary.isna().sum()
# Out:
# 0

# %% [markdown]
# Replace the Null values in Comapany with mode

# %%
df.Company.isna().sum()
df['Company'] = df['Company'].fillna(df['Company'].mode())
df.Company.isna().sum()
df
# Out:
#      Company   Age  Salary     Place Country
# 0        TCS  20.0  5000.0   Chennai   India
# 1    Infosys  30.0  5000.0    Mumbai   India
# 2        TCS  35.0  2300.0  Calcutta   India
# 3    Infosys  40.0  3000.0     Delhi   India
# 4        TCS  23.0  4000.0    Mumbai   India
# ..       ...   ...     ...       ...     ...
# 144  Infosys  22.0  8787.0  Calcutta   India
# 145  Infosys  44.0  4034.0     Delhi   India
# 146      TCS  33.0  5034.0    Mumbai   India
# 147  Infosys  22.0  8202.0    Cochin   India
# 148      NaN   NaN  5000.0       NaN     NaN
#
# [149 rows x 5 columns]

# %% [markdown]
# Replace the null value in Salary with median

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].median())
df
# Out:
#      Company   Age  Salary     Place Country
# 0        TCS  20.0  5000.0   Chennai   India
# 1    Infosys  30.0  5000.0    Mumbai   India
# 2        TCS  35.0  2300.0  Calcutta   India
# 3    Infosys  40.0  3000.0     Delhi   India
# 4        TCS  23.0  4000.0    Mumbai   India
# ..       ...   ...     ...       ...     ...
# 144  Infosys  22.0  8787.0  Calcutta   India
# 145  Infosys  44.0  4034.0     Delhi   India
# 146      TCS  33.0  5034.0    Mumbai   India
# 147  Infosys  22.0  8202.0    Cochin   India
# 148      NaN   NaN  5000.0       NaN     NaN
#
# [149 rows x 5 columns]

# %% [markdown]
# Replace the null value in age with mean

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df
# Out:
#      Company        Age  Salary     Place Country
# 0        TCS  20.000000  5000.0   Chennai   India
# 1    Infosys  30.000000  5000.0    Mumbai   India
# 2        TCS  35.000000  2300.0  Calcutta   India
# 3    Infosys  40.000000  3000.0     Delhi   India
# 4        TCS  23.000000  4000.0    Mumbai   India
# ..       ...        ...     ...       ...     ...
# 144  Infosys  22.000000  8787.0  Calcutta   India
# 145  Infosys  44.000000  4034.0     Delhi   India
# 146      TCS  33.000000  5034.0    Mumbai   India
# 147  Infosys  22.000000  8202.0    Cochin   India
# 148      NaN  30.484615  5000.0       NaN     NaN
#
# [149 rows x 5 columns]

# %% [markdown]
# Filter the data with age>40 and Salary<5000

# %%
display(df.loc[(df['Salary']<5000) & (df['Age']< 40)])
# Out:
#         Company        Age  Salary       Place Country
# 2           TCS  35.000000  2300.0    Calcutta   India
# 4           TCS  23.000000  4000.0      Mumbai   India
# 11          CTS  34.000000  1089.0    Calcutta   India
# 13          CTS  18.000000  1234.0      Mumbai   India
# 15          TCS  23.000000  3000.0       Delhi   India
# 16      Infosys  23.000000  3030.0  Podicherry   India
# 20          TCS  37.000000  3045.0    Calcutta   India
# 22          TCS  21.000000  4824.0      Mumbai   India
# 29          CTS  35.000000  2034.0      Cochin   India
# 31          CTS  20.000000  2934.0      Mumbai   India
# 38          TCS  34.000000  2300.0    Calcutta   India
# 40          TCS  24.000000  4345.0    Calcutta   India
# 47          CTS  32.000000  1089.0      Mumbai   India
# 49          CTS  19.000000  1234.0      Cochin   India
# 51          NaN  24.000000  3000.0      Mumbai   India
# 52      Infosys  21.000000  3030.0    Calcutta   India
# 56          TCS  38.000000  3045.0       Noida   India
# 58          TCS  23.000000  4824.0    Calcutta   India
# 65          CTS  31.000000  2034.0   Hyderabad   India
# 67   Congnizant  21.000000  2934.0      Mumbai   India
# 74          TCS  37.000000  2300.0      Mumbai   India
# 76          TCS  32.000000  4000.0       Noida   India
# 83          CTS  33.000000  1089.0     Chennai   India
# 85          CTS  17.000000  1234.0    Calcutta   India
# 87          TCS  21.000000  3000.0      Mumbai   India
# 88      Infosys   0.000000  3030.0    Calcutta   India
# 92          TCS   0.000000  3045.0       Delhi   India
# 94          TCS  22.000000  4824.0    Calcutta   India
# 101         CTS   0.000000  2034.0  Podicherry   India
# 103         CTS  22.000000  2934.0    Calcutta   India
# 110         TCS  33.000000  2300.0       Delhi   India
# 111     Infosys   0.000000  3234.0      Mumbai   India
# 112         TCS  22.000000  4324.0      Cochin   India
# 119         CTS  33.000000  1089.0       Noida   India
# 121         CTS   0.000000  1234.0    Calcutta   India
# 123         NaN  30.484615  3454.0    Calcutta   India
# 128         TCS  33.000000  3045.0   Hyderabad   India
# 130         TCS  21.000000  4824.0      Mumbai   India
# 137         CTS  31.000000  2034.0      Mumbai   India
# 139  Congnizant  22.000000  2934.0       Noida   India

# %% [markdown]
# Draw the pie chart for place and Company

# %%
import matplotlib.pyplot as plt
df.groupby(['Place','Company']).sum().plot(kind='pie', subplots=True, figsize=(30, 50),autopct='%1.1f%%')
plt.show()

# %% [markdown]
# Find the mean age with repective to the Company

# %%
df2 = df.groupby('Company')['Age'].mean()
print(df2.astype('int64'))
print(df2,end="\n\n")
# Out:
# Company
# CTS                          32
# Congnizant                   21
# Infosys                      32
# Infosys Pvt Lmt              21
# TCS                          28
# Tata Consultancy Services    33
# Name: Age, dtype: int64
# Company
# CTS                          32.194444
# Congnizant                   21.500000
# Infosys                      32.241709
# Infosys Pvt Lmt              21.500000
# TCS                          28.752395
# Tata Consultancy Services    33.500000
# Name: Age, dtype: float64

# %% [markdown]
# Draw an histogram chart for age, Salary

# %%
df.hist(['Age','Salary'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f966eb957d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f966eba9a50>]],
#       dtype=object)

# %% [markdown]
# Find the mean, count, median of salary with repective to the place

# %%
df.groupby(['Place']).Salary.mean().astype('int32')
# Out:
# Place
# Bhopal        7000
# Calcutta      5028
# Chennai       5876
# Cochin        5048
# Delhi         4801
# Hyderabad     4537
# Mumbai        4896
# Nagpur        8000
# Noida         4463
# Podicherry    4782
# Pune          7000
# Name: Salary, dtype: int32

# %%
df.groupby(['Place']).Salary.value_counts()
# Out:
# Place       Salary
# Bhopal      7000.0    1
# Calcutta    5000.0    6
#             8787.0    3
#             1234.0    2
#             2300.0    2
#                      ..
# Podicherry  2034.0    1
#             3030.0    1
#             9284.0    1
# Pune        5000.0    1
#             9000.0    1
# Name: Salary, Length: 97, dtype: int64

# %%
df.groupby(['Place']).Salary.median()
# Out:
# Place
# Bhopal        7000.0
# Calcutta      5000.0
# Chennai       5635.0
# Cochin        5000.0
# Delhi         4034.0
# Hyderabad     4517.0
# Mumbai        5000.0
# Nagpur        8000.0
# Noida         4500.0
# Podicherry    3030.0
# Pune          7000.0
# Name: Salary, dtype: float64
